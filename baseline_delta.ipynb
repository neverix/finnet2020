# %%
import numpy as np
import pandas as pd
import tqdm

import catboost as cat
from catboost import CatBoostClassifier

# %% [markdown]
# ## Загрузим данные

# %%
# %%time
edges = pd.read_csv('./edges.csv')
ids = pd.read_csv('./ids.csv')
vertices = pd.read_csv('./vertices.csv')
# Out:
# CPU times: user 2.85 s, sys: 160 ms, total: 3.01 s
# Wall time: 1.35 s

# %%
vertices['main_okved'] = vertices['main_okved'].astype(str)

# %%
np.random.seed(3333)

# %%
counts = edges.id_1.append(edges.id_2).reset_index(drop=True).value_counts()
counts = pd.DataFrame(counts.rename("id"))
merges = counts.merge(ids, left_index=True, right_on="id", how="left", indicator=True)
merges.index = merges.id
counts = counts[merges._merge == "both"]
counts /= counts.sum() / 100
counts
# Out:
#                id
# 524354   3.529384
# 61537    2.668124
# 1142564  2.292733
# 300432   2.030198
# 58408    1.932786
# ...           ...
# 1392199  0.605852
# 912470   0.605852
# 1526265  0.604664
# 1523148  0.602288
# 373737   0.599912
#
# [100 rows x 1 columns]

# %%
counts_div = np.ceil(counts * 1000).astype("int")
ceil_sum = counts_div.sum()
v = ids.id.iloc[0]
counts_div.id.loc[v] = int(counts_div.id.loc[v] + 100000 - ceil_sum)
counts_div, counts_div.sum()
# Out:
# (           id
#  524354   3484
#  61537    2669
#  1142564  2293
#  300432   2031
#  58408    1933
#  ...       ...
#  1392199   606
#  912470    606
#  1526265   605
#  1523148   603
#  373737    600
#
#  [100 rows x 1 columns], id    100000
#  dtype: int64)

# %% [markdown]
# ## Обучим модель

# %%
result = pd.DataFrame(columns=['id_1', 'id_2'])

# %%
# для каждой вершины из ids с помощью catboost найдем 1000 самых вероятных ребер
for i, (v,) in tqdm.tqdm(counts_div.iterrows()):
    # соберем датасет из всех возможных вершин
    # вершины имеющие в исходных данных ребро с i обозначим 1, остальные 0
    # учтем то, что вершина i может быть как среди id_1, так и среди id_2
    df1 = edges[edges['id_1'] == i].reset_index()
    df2 = edges[edges['id_2'] == i].reset_index()

    df = df1[['id_2', 'id_1']].rename(columns={'id_1':'id_2', 'id_2':'id_1'}).append(df2[['id_1', 'id_2']])
    df['target'] = 1
    
    df = vertices.set_index('id').join(df.set_index('id_1')['target']).fillna(0)
    
    
    X = df[['main_okved', 'region_code', 'company_type']]
    y = df['target']
    
    model = CatBoostClassifier(iterations=500, task_type="GPU", gpu_ram_part=0.5, random_seed=3333, verbose=False)
    cat_features = [0,1,2] # все признаки категориальные
    
    model.fit(X, y, cat_features)

    preds = model.predict_proba(X)[:,1]

    df['preds'] = preds
    df['id_2'] = i
    
    # возьмем первую 1000 предсказанных ребер, исключив те, про которые мы уже знали
    res = df[df['target'] != 1].sort_values(by='preds', ascending=False).iloc[:v].reset_index()[['id', 'id_2']]
    res.columns = ['id_1', 'id_2']
    
    result = result.append(res, ignore_index=True, sort=False)
# Out:
# 0it [00:00, ?it/s]Warning: less than 75% gpu memory available for training. Free: 5978.75 Total: 7979.1875
#
#
# 1it [00:38, 38.36s/it]Warning: less than 75% gpu memory available for training. Free: 5971.3125 Total: 7979.1875
#
#
# 2it [01:16, 38.37s/it]Warning: less than 75% gpu memory available for training. Free: 5972.4375 Total: 7979.1875
#
#
# 3it [01:57, 39.00s/it]Warning: less than 75% gpu memory available for training. Free: 5960.375 Total: 7979.1875
#
#
# 4it [02:35, 38.75s/it]Warning: less than 75% gpu memory available for training. Free: 5958.25 Total: 7979.1875
#
#
# 5it [03:08, 37.19s/it]Warning: less than 75% gpu memory available for training. Free: 5958.625 Total: 7979.1875
#
#
# 6it [03:46, 37.27s/it]Warning: less than 75% gpu memory available for training. Free: 5954.9375 Total: 7979.1875
#
#
# 7it [04:19, 36.03s/it]Warning: less than 75% gpu memory available for training. Free: 5956.6875 Total: 7979.1875
#
#
# 8it [04:53, 35.51s/it]Warning: less than 75% gpu memory available for training. Free: 5958.375 Total: 7979.1875
#
#
# 9it [05:33, 36.83s/it]Warning: less than 75% gpu memory available for training. Free: 5948.25 Total: 7979.1875
#
#
# 10it [06:10, 36.75s/it]Warning: less than 75% gpu memory available for training. Free: 5941.6875 Total: 7979.1875
#
#
# 11it [06:47, 36.95s/it]Warning: less than 75% gpu memory available for training. Free: 5936.3125 Total: 7979.1875
#
#
# 12it [07:25, 37.15s/it]Warning: less than 75% gpu memory available for training. Free: 5936.375 Total: 7979.1875
#
#
# 13it [08:03, 37.36s/it]Warning: less than 75% gpu memory available for training. Free: 5941.4375 Total: 7979.1875
#
#
# 14it [08:42, 37.92s/it]Warning: less than 75% gpu memory available for training. Free: 5926.375 Total: 7979.1875
#
#
# 15it [09:19, 37.68s/it]Warning: less than 75% gpu memory available for training. Free: 5926.625 Total: 7979.1875
#
#
# 16it [09:57, 37.72s/it]Warning: less than 75% gpu memory available for training. Free: 5944.625 Total: 7979.1875
#
#
# 17it [10:33, 37.32s/it]Warning: less than 75% gpu memory available for training. Free: 5945.875 Total: 7979.1875
#
#
# 18it [11:10, 37.09s/it]Warning: less than 75% gpu memory available for training. Free: 5946.625 Total: 7979.1875
#
#
# 19it [11:49, 37.73s/it]Warning: less than 75% gpu memory available for training. Free: 5946.4375 Total: 7979.1875
#
#
# 20it [12:28, 38.17s/it]Warning: less than 75% gpu memory available for training. Free: 5949.625 Total: 7979.1875
#
#
# 21it [13:03, 37.08s/it]Warning: less than 75% gpu memory available for training. Free: 5950.0625 Total: 7979.1875
#
#
# 22it [13:39, 36.92s/it]Warning: less than 75% gpu memory available for training. Free: 5949.3125 Total: 7979.1875
#
#
# 23it [14:12, 35.66s/it]Warning: less than 75% gpu memory available for training. Free: 5949.6875 Total: 7979.1875
#
#
# 24it [14:49, 36.18s/it]Warning: less than 75% gpu memory available for training. Free: 5949.9375 Total: 7979.1875
#
#
# 25it [15:26, 36.37s/it]Warning: less than 75% gpu memory available for training. Free: 5949.4375 Total: 7979.1875
#
#
# 26it [16:04, 36.74s/it]Warning: less than 75% gpu memory available for training. Free: 5950.0625 Total: 7979.1875
#
#
# 27it [16:40, 36.44s/it]Warning: less than 75% gpu memory available for training. Free: 5946.4375 Total: 7979.1875
#
#
# 28it [17:18, 37.13s/it]Warning: less than 75% gpu memory available for training. Free: 5948.8125 Total: 7979.1875
#
#
# 29it [17:54, 36.80s/it]Warning: less than 75% gpu memory available for training. Free: 5948.6875 Total: 7979.1875
#
#
# 30it [18:36, 38.17s/it]Warning: less than 75% gpu memory available for training. Free: 5948.9375 Total: 7979.1875
#
#
# 31it [19:16, 38.69s/it]Warning: less than 75% gpu memory available for training. Free: 5950.5 Total: 7979.1875
#
#
# 32it [19:49, 37.23s/it]Warning: less than 75% gpu memory available for training. Free: 5950.9375 Total: 7979.1875
#
#
# 33it [20:26, 37.18s/it]Warning: less than 75% gpu memory available for training. Free: 5947.375 Total: 7979.1875
#
#
# 34it [21:04, 37.25s/it]Warning: less than 75% gpu memory available for training. Free: 5950.9375 Total: 7979.1875
#
#
# 35it [21:38, 36.19s/it]Warning: less than 75% gpu memory available for training. Free: 5951.3125 Total: 7979.1875
#
#
# 36it [22:14, 36.21s/it]Warning: less than 75% gpu memory available for training. Free: 5952.625 Total: 7979.1875
#
#
# 37it [22:48, 35.73s/it]Warning: less than 75% gpu memory available for training. Free: 5952.6875 Total: 7979.1875
#
#
# 38it [23:27, 36.66s/it]Warning: less than 75% gpu memory available for training. Free: 5949.25 Total: 7979.1875
#
#
# 39it [24:07, 37.65s/it]Warning: less than 75% gpu memory available for training. Free: 5950.75 Total: 7979.1875
#
#
# 40it [24:46, 37.94s/it]Warning: less than 75% gpu memory available for training. Free: 5954.4375 Total: 7979.1875
#
#
# 41it [25:26, 38.57s/it]Warning: less than 75% gpu memory available for training. Free: 5953.4375 Total: 7979.1875
#
#
# 42it [26:04, 38.55s/it]Warning: less than 75% gpu memory available for training. Free: 5953.9375 Total: 7979.1875
#
#
# 43it [26:40, 37.70s/it]Warning: less than 75% gpu memory available for training. Free: 5954.3125 Total: 7979.1875
#
#
# 44it [27:12, 35.90s/it]Warning: less than 75% gpu memory available for training. Free: 5953.9375 Total: 7979.1875
#
#
# 45it [27:49, 36.19s/it]Warning: less than 75% gpu memory available for training. Free: 5954.1875 Total: 7979.1875
#
#
# 46it [28:24, 35.88s/it]Warning: less than 75% gpu memory available for training. Free: 5954.875 Total: 7979.1875
#
#
# 47it [29:00, 36.00s/it]Warning: less than 75% gpu memory available for training. Free: 5955.5625 Total: 7979.1875
#
#
# 48it [29:40, 37.14s/it]Warning: less than 75% gpu memory available for training. Free: 5954.5625 Total: 7979.1875
#
#
# 49it [30:18, 37.41s/it]Warning: less than 75% gpu memory available for training. Free: 5955 Total: 7979.1875
#
#
# 50it [30:52, 36.48s/it]Warning: less than 75% gpu memory available for training. Free: 5954.875 Total: 7979.1875
#
#
# 51it [31:29, 36.51s/it]Warning: less than 75% gpu memory available for training. Free: 5954.9375 Total: 7979.1875
#
#
# 52it [32:04, 36.07s/it]Warning: less than 75% gpu memory available for training. Free: 5955.125 Total: 7979.1875
#
#
# 53it [32:40, 36.04s/it]Warning: less than 75% gpu memory available for training. Free: 5955.3125 Total: 7979.1875
#
#
# 54it [33:15, 35.74s/it]Warning: less than 75% gpu memory available for training. Free: 5954.8125 Total: 7979.1875
#
#
# 55it [33:51, 35.83s/it]Warning: less than 75% gpu memory available for training. Free: 5955.3125 Total: 7979.1875
#
#
# 56it [34:32, 37.47s/it]Warning: less than 75% gpu memory available for training. Free: 5954.5 Total: 7979.1875
#
#
# 57it [35:13, 38.42s/it]Warning: less than 75% gpu memory available for training. Free: 5954.5625 Total: 7979.1875
#
#
# 58it [35:49, 37.87s/it]Warning: less than 75% gpu memory available for training. Free: 5955.4375 Total: 7979.1875
#
#
# 59it [36:24, 36.96s/it]Warning: less than 75% gpu memory available for training. Free: 5954.6875 Total: 7979.1875
#
#
# 60it [37:02, 37.30s/it]Warning: less than 75% gpu memory available for training. Free: 5955.3125 Total: 7979.1875
#
#
# 61it [37:42, 38.02s/it]Warning: less than 75% gpu memory available for training. Free: 5955.25 Total: 7979.1875
#
#
# 62it [38:21, 38.37s/it]Warning: less than 75% gpu memory available for training. Free: 5954.9375 Total: 7979.1875
#
#
# 63it [39:00, 38.33s/it]Warning: less than 75% gpu memory available for training. Free: 5954.5625 Total: 7979.1875
#
#
# 64it [39:32, 36.58s/it]Warning: less than 75% gpu memory available for training. Free: 5955.3125 Total: 7979.1875
#
#
# 65it [40:09, 36.78s/it]Warning: less than 75% gpu memory available for training. Free: 5954.8125 Total: 7979.1875
#
#
# 66it [40:41, 35.28s/it]Warning: less than 75% gpu memory available for training. Free: 5955.0625 Total: 7979.1875
#
#
# 67it [41:17, 35.37s/it]Warning: less than 75% gpu memory available for training. Free: 5954.6875 Total: 7979.1875
#
#
# 68it [41:53, 35.78s/it]Warning: less than 75% gpu memory available for training. Free: 5955.3125 Total: 7979.1875
#
#
# 69it [42:28, 35.31s/it]Warning: less than 75% gpu memory available for training. Free: 5955.3125 Total: 7979.1875
#
#
# 70it [43:02, 35.05s/it]Warning: less than 75% gpu memory available for training. Free: 5954.9375 Total: 7979.1875
#
#
# 71it [43:38, 35.33s/it]Warning: less than 75% gpu memory available for training. Free: 5955.5625 Total: 7979.1875
#
#
# 72it [44:12, 34.80s/it]Warning: less than 75% gpu memory available for training. Free: 5954.9375 Total: 7979.1875
#
#
# 73it [44:47, 35.04s/it]Warning: less than 75% gpu memory available for training. Free: 5956.125 Total: 7979.1875
#
#
# 74it [45:22, 35.00s/it]Warning: less than 75% gpu memory available for training. Free: 5956.625 Total: 7979.1875
#
#
# 75it [45:55, 34.31s/it]Warning: less than 75% gpu memory available for training. Free: 5956.375 Total: 7979.1875
#
#
# 76it [46:32, 35.33s/it]Warning: less than 75% gpu memory available for training. Free: 5956.375 Total: 7979.1875
#
#
# 77it [47:07, 34.94s/it]Warning: less than 75% gpu memory available for training. Free: 5952.5625 Total: 7979.1875
#
#
# 78it [47:44, 35.84s/it]Warning: less than 75% gpu memory available for training. Free: 5951.9375 Total: 7979.1875
#
#
# 79it [48:21, 36.15s/it]Warning: less than 75% gpu memory available for training. Free: 5957.25 Total: 7979.1875
#
#
# 80it [48:56, 35.65s/it]Warning: less than 75% gpu memory available for training. Free: 5956.5 Total: 7979.1875
#
#
# 81it [49:30, 35.30s/it]Warning: less than 75% gpu memory available for training. Free: 5957.5625 Total: 7979.1875
#
#
# 82it [50:07, 35.64s/it]Warning: less than 75% gpu memory available for training. Free: 5957.625 Total: 7979.1875
#
#
# 83it [50:45, 36.45s/it]Warning: less than 75% gpu memory available for training. Free: 5957.5 Total: 7979.1875
#
#
# 84it [51:18, 35.53s/it]Warning: less than 75% gpu memory available for training. Free: 5957 Total: 7979.1875
#
#
# 85it [51:56, 36.07s/it]Warning: less than 75% gpu memory available for training. Free: 5957.875 Total: 7979.1875
#
#
# 86it [52:32, 36.13s/it]Warning: less than 75% gpu memory available for training. Free: 5957.75 Total: 7979.1875
#
#
# 87it [53:07, 35.91s/it]Warning: less than 75% gpu memory available for training. Free: 5957.625 Total: 7979.1875
#
#
# 88it [53:43, 35.66s/it]Warning: less than 75% gpu memory available for training. Free: 5958 Total: 7979.1875
#
#
# 89it [54:15, 34.69s/it]Warning: less than 75% gpu memory available for training. Free: 5957.625 Total: 7979.1875
#
#
# 90it [54:48, 34.13s/it]Warning: less than 75% gpu memory available for training. Free: 5957.875 Total: 7979.1875
#
#
# 91it [55:25, 35.06s/it]Warning: less than 75% gpu memory available for training. Free: 5958.375 Total: 7979.1875
#
#
# 92it [56:03, 35.83s/it]Warning: less than 75% gpu memory available for training. Free: 5958 Total: 7979.1875
#
#
# 93it [56:37, 35.48s/it]Warning: less than 75% gpu memory available for training. Free: 5957.75 Total: 7979.1875
#
#
# 94it [57:11, 34.90s/it]Warning: less than 75% gpu memory available for training. Free: 5957.625 Total: 7979.1875
#
#
# 95it [57:46, 35.10s/it]Warning: less than 75% gpu memory available for training. Free: 5958.25 Total: 7979.1875
#
#
# 96it [58:21, 35.06s/it]Warning: less than 75% gpu memory available for training. Free: 5958 Total: 7979.1875
#
#
# 97it [58:55, 34.59s/it]Warning: less than 75% gpu memory available for training. Free: 5957.75 Total: 7979.1875
#
#
# 98it [59:31, 35.07s/it]Warning: less than 75% gpu memory available for training. Free: 5958.5 Total: 7979.1875
#
#
# 99it [1:00:03, 34.21s/it]Warning: less than 75% gpu memory available for training. Free: 5958.125 Total: 7979.1875
#
#
# 100it [1:00:40, 36.41s/it]

# %% [markdown]
# ## Результат готов к отправке

# %%
result.to_csv('submission.csv', index = False)

# %%
result.drop_duplicates(inplace=False)
# Out:
#            id_1    id_2
# 0        622334  524354
# 1        160171  524354
# 2        230859  524354
# 3        474353  524354
# 4         54938  524354
# ...         ...     ...
# 103479  1060892  373737
# 103480   944705  373737
# 103481   859978  373737
# 103482   867749  373737
# 103483    52674  373737
#
# [101128 rows x 2 columns]

# %%
result
# Out:
#            id_1    id_2
# 0        622334  524354
# 1        160171  524354
# 2        230859  524354
# 3        474353  524354
# 4         54938  524354
# ...         ...     ...
# 103479  1060892  373737
# 103480   944705  373737
# 103481   859978  373737
# 103482   867749  373737
# 103483    52674  373737
#
# [103484 rows x 2 columns]

# %%
result.drop_duplicates(inplace=False)[:100000].to_csv('submission.csv', index = False)
